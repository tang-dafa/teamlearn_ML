# %% [markdown]
# # 大纲
# ![%E6%9C%AA%E5%91%BD%E5%90%8D%E5%9B%BE%E7%89%87.png](attachment:%E6%9C%AA%E5%91%BD%E5%90%8D%E5%9B%BE%E7%89%87.png)
# ![svm2.png](attachment:svm2.png)
#
# # 硬间隔
# ## 函数间隔
# ![svm3.png](attachment:svm3.png)
# 可以表示分类预测的正确度及确信度
# ## 几何间隔
# ![svm4.png](attachment:svm4.png)
# ## 几何间隔与函数间隔的关系
# ![svm5.png](attachment:svm5.png)
# ## 间隔最大化
# ![svm6.png](attachment:svm6.png)
# ![image.png](attachment:image.png)
# 这一步求最大到求最小的转换是拉格郎日对偶
# ## 算法-最大间隔法
# ![7.1.png](attachment:7.1.png)
# ![7.1.2.png](attachment:7.1.2.png)

# %% [markdown]
# # 软间隔
#
# ## 原始问题
# ![rj1.png](attachment:rj1.png)
# ## 原始问题的对偶问题
# ![rj2.png](attachment:rj2.png)
# ![rj3.png](attachment:rj3.png)
# ## 算法
# ![7.3.png](attachment:7.3.png)
# ![7.3.2.png](attachment:7.3.2.png)

# %% [markdown]
# # 核函数
